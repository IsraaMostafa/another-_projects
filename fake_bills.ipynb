# %% [markdown]
# <a href="https://colab.research.google.com/github/IsraaMostafa/another-_projects/blob/main/fake_bills.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fake_bills_data =pd.read_csv('/content/drive/MyDrive/fake_bills.csv',sep=";")

# %%
fake_bills_data
# Out:
#       is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0           True    171.81       104.86        104.95        4.52       2.89
# 1           True    171.46       103.36        103.66        3.77       2.99
# 2           True    172.69       104.48        103.50        4.40       2.94
# 3           True    171.36       103.91        103.94        3.62       3.01
# 4           True    171.73       104.28        103.46        4.04       3.48
# ...          ...       ...          ...           ...         ...        ...
# 1495       False    171.75       104.38        104.17        4.42       3.09
# 1496       False    172.19       104.63        104.44        5.27       3.37
# 1497       False    171.80       104.01        104.12        5.51       3.36
# 1498       False    172.06       104.28        104.06        5.17       3.46
# 1499       False    171.47       104.15        103.82        4.63       3.37
#
#       length
# 0     112.83
# 1     113.09
# ...

# %%
fake_bills_data .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1500 non-null   bool
#  1   diagonal      1500 non-null   float64
#  2   height_left   1500 non-null   float64
#  3   height_right  1500 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1500 non-null   float64
#  6   length        1500 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 71.9 KB

# %%
fake_bills_data .describe()
# Out:
#           diagonal  height_left  height_right   margin_low    margin_up  \
# count  1500.000000  1500.000000   1500.000000  1463.000000  1500.000000
# mean    171.958440   104.029533    103.920307     4.485967     3.151473
# std       0.305195     0.299462      0.325627     0.663813     0.231813
# min     171.040000   103.140000    102.820000     2.980000     2.270000
# 25%     171.750000   103.820000    103.710000     4.015000     2.990000
# 50%     171.960000   104.040000    103.920000     4.310000     3.140000
# 75%     172.170000   104.230000    104.150000     4.870000     3.310000
# max     173.010000   104.880000    104.950000     6.900000     3.910000
#
#            length
# count  1500.00000
# mean    112.67850
# std       0.87273
# min     109.49000
# 25%     112.03000
# 50%     112.96000
# 75%     113.34000
# max     114.44000

# %%
fake_bills_data ['is_genuine']=fake_bills_data ['is_genuine'].astype('int')

# %%
fake_bills_data.head(20)
# Out:
#     is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0            1    171.81       104.86        104.95        4.52       2.89
# 1            1    171.46       103.36        103.66        3.77       2.99
# 2            1    172.69       104.48        103.50        4.40       2.94
# 3            1    171.36       103.91        103.94        3.62       3.01
# 4            1    171.73       104.28        103.46        4.04       3.48
# 5            1    172.17       103.74        104.08        4.42       2.95
# 6            1    172.34       104.18        103.85        4.58       3.26
# 7            1    171.88       103.76        104.08        3.98       2.92
# 8            1    172.47       103.92        103.67        4.00       3.25
# 9            1    172.47       104.07        104.02        4.04       3.25
# 10           1    171.83       104.14        103.62        3.16       3.18
# ...

# %%
fake_bills_data
# Out:
#       is_genuine  diagonal  height_left  height_right margin_low  margin_up  \
# 0              1    171.81       104.86        104.95       4.52       2.89
# 1              1    171.46       103.36        103.66       3.77       2.99
# 2              1    172.69       104.48        103.50        4.4       2.94
# 3              1    171.36       103.91        103.94       3.62       3.01
# 4              1    171.73       104.28        103.46       4.04       3.48
# ...          ...       ...          ...           ...        ...        ...
# 1495           0    171.75       104.38        104.17       4.42       3.09
# 1496           0    172.19       104.63        104.44       5.27       3.37
# 1497           0    171.80       104.01        104.12       5.51       3.36
# 1498           0    172.06       104.28        104.06       5.17       3.46
# 1499           0    171.47       104.15        103.82       4.63       3.37
#
#       length
# 0     112.83
# 1     113.09
# ...

# %%
fake_bills_data.isnull().sum()
# Out:
# is_genuine      0
# diagonal        0
# height_left     0
# height_right    0
# margin_low      0
# margin_up       0
# length          0
# dtype: int64

# %%
fake_bills_data['margin_low'] = pd.to_numeric(fake_bills_data['margin_low'], errors='coerce')#replacing invalid values with NaN,

# %%
fake_bills_data['margin_low'] = fake_bills_data['margin_low'].fillna(fake_bills_data['margin_low'].mean())

# %%
fake_bills_data .isnull().sum()
# Out:
# is_genuine      0
# diagonal        0
# height_left     0
# height_right    0
# margin_low      0
# margin_up       0
# length          0
# dtype: int64

# %%
fig,axes= plt.subplots(3,2,figsize=(7,7))
fig1 = sns.histplot(data = fake_bills_data,x = "height_left",kde = True,ax = axes[0,0],color='black')
fig2 = sns.histplot(data = fake_bills_data,x = "height_right",kde = True,ax = axes[0,1],color='black')
fig3 = sns.histplot(data = fake_bills_data,x = "margin_low",kde = True,ax = axes[1,0],color='black')
fig4 = sns.histplot(data = fake_bills_data,x = "margin_up",kde = True,ax = axes[1,1],color='black')
fig5 = sns.histplot(data= fake_bills_data,x = "diagonal",kde = True,ax = axes[2,0],color='black')
fig6 = sns.histplot(data= fake_bills_data,x = "length",kde = True,ax = axes[2,1],color='black')
plt.show()

# %%
corr = fake_bills_data.corr()
sns.heatmap(corr, annot=True, fmt='.2f', cbar=True, cmap='Reds')
# Out:
# <Axes: >

# %%
X = fake_bills_data.drop(['is_genuine'], axis = 1)
X.head()
# Out:
#    diagonal  height_left  height_right  margin_low  margin_up  length
# 0    171.81       104.86        104.95        4.52       2.89  112.83
# 1    171.46       103.36        103.66        3.77       2.99  113.09
# 2    172.69       104.48        103.50        4.40       2.94  113.16
# 3    171.36       103.91        103.94        3.62       3.01  113.51
# 4    171.73       104.28        103.46        4.04       3.48  112.54

# %%
Y=fake_bills_data['is_genuine']
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: is_genuine, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=4)

# %%
from sklearn.preprocessing import StandardScaler# solving normalization problem
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier#KNN
from sklearn.metrics import classification_report

knn_model = KNeighborsClassifier(n_neighbors =6)
knn_model.fit(X_train, Y_train)
y_pred_knn = knn_model.predict(X_test)
print(classification_report(Y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       105
#            1       0.99      0.99      0.99       195
#
#     accuracy                           0.99       300
#    macro avg       0.99      0.99      0.99       300
# weighted avg       0.99      0.99      0.99       300

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(knn_model, X_train, Y_train, cv=5)
print("Accuracy: ", scores.mean())
# Out:
# Accuracy:  0.9891666666666667

# %%
#logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
log_model=LogisticRegression()
log_model.fit (X_train,Y_train)
Y_predict_log=log_model.predict(X_test)
print (classification_report(Y_test,Y_predict_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       105
#            1       0.99      0.99      0.99       195
#
#     accuracy                           0.99       300
#    macro avg       0.99      0.99      0.99       300
# weighted avg       0.99      0.99      0.99       300

# %%
scores = cross_val_score(log_model, X_train, Y_train, cv=5)
print("Accuracy: ", scores.mean())
# Out:
# Accuracy:  0.9891666666666665

# %%
#NAIVE BAYES
from sklearn.naive_bayes import GaussianNB

NB_model = GaussianNB()
NB_model = NB_model.fit(X_train, Y_train)
Y_prediction_NB = NB_model.predict(X_test)
print(classification_report(Y_test, Y_prediction_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       105
#            1       0.99      0.99      0.99       195
#
#     accuracy                           0.99       300
#    macro avg       0.99      0.99      0.99       300
# weighted avg       0.99      0.99      0.99       300

# %%
scores = cross_val_score(NB_model, X_train, Y_train, cv=5)
print("Accuracy: ", scores.mean())
# Out:
# Accuracy:  0.9916666666666666
